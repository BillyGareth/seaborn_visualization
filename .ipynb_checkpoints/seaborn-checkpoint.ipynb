# %% [markdown]
# # <font color='maroon'> Data Visualization using seaborn <font>

# %% [markdown]
# # <font color='grey'> Install Seaborn and it's Dependancies <font>

# %% [markdown]
# installations-conda install seaborn/pip install seaborn
#
# dependencies-matplotlib,SciPy,Numpy,Pandas

# %% [markdown]
# # <font color='silver'>Statistical Relationship-relpot()<font>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
b_g=pd.read_csv('train1.csv')

# %%
b_g
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
sns.relplot(x='Item_Weight',y='Item_Fat_Content',data=b_g)

# %%
fats_dict={'Low Fat':0,'Regular':1,'low fat':0,'LF':0,'reg':1}

# %%
b_g['Item_Fat_content']=b_g['Item_Fat_Content'].replace(fats_dict,regex=True)

# %%
sns.relplot(x='Item_Weight',y='Item_Type',data=b_g)

# %% [markdown]
# # <font color='sky blue'> Hue Semantic adding dimension

# %%
sns.relplot(x='Item_Weight',y='Item_Type',hue='Outlet_Establishment_Year',data=b_g)

# %% [markdown]
# # <font color = 'sky blue'> line plot

# %%
sns.relplot(x='Item_Weight',y='Item_MRP',kind='line',data=b_g)

# %% [markdown]
# # <font color ='light blue'> Categorical Data using catplot()

# %%
by=pd.read_excel('population_insecure.xlsx')

# %%
by
# Out:
#   situation  number insecure in millions
# 0    normal                          1.3
# 1   drought                          3.7

# %%
sns.catplot(x='situation',y='number insecure in millions',data=by)

# %%
nc=pd.read_csv('novcor.csv')

# %%
nc
# Out:
#      Sno                 Date   Province/State Country          Last Update  \
# 0      1      1/22/2020 12:00            Anhui   China      1/22/2020 12:00
# 1      2      1/22/2020 12:00          Beijing   China      1/22/2020 12:00
# 2      3      1/22/2020 12:00        Chongqing   China      1/22/2020 12:00
# 3      4      1/22/2020 12:00           Fujian   China      1/22/2020 12:00
# 4      5      1/22/2020 12:00            Gansu   China      1/22/2020 12:00
# ..   ...                  ...              ...     ...                  ...
# 626  627  2020-02-02 21:00:00       Boston, MA      US  2020-01-02 19:43:00
# 627  628  2020-02-02 21:00:00  Los Angeles, CA      US  2020-01-02 19:53:00
# 628  629  2020-02-02 21:00:00       Orange, CA      US  2020-01-02 19:53:00
# 629  630  2020-02-02 21:00:00      Seattle, WA      US  2020-01-02 19:43:00
# 630  631  2020-02-02 21:00:00        Tempe, AZ      US  2020-01-02 19:43:00
#
#      Confirmed  Deaths  Recovered
# ...

# %%
sns.catplot(x='Confirmed',y='Country',data=nc)
#kind=boxen,violin.....

# %% [markdown]
# # <font color='light blue'> Distribution of Datasets using distplot()<font>

# %% [markdown]
# # <font color = 'sky blue' > for Univariate dataset <font>

# %%
from scipy import stats
import numpy as np
import seaborn as sns

# %%
b=np.random.normal(loc=5,size=100,scale=3)

# %%
sns.distplot(b)

# %% [markdown]
# # <font color = 'sky blue' > for Bivariate dataset <font>

# %%
import pandas as pd

# %%
m=pd.DataFrame({'Cars':[12,21,13,14,17,18],'Bikes':[20,22,24,26,30,24],'Planes':[13,16,14,12,13,10],'Ships':[23,32,24,25,31,28],'Others':[1,2,3,4,5,6]})

# %%
n=pd.DataFrame({'Cars':[23,34,18,20,24,19],'Bikes':[30,31,32,26,21,18],'Planes':[21,20,18,19,16,13],'Ships':[35,18,13,30,32,27],'Others':[16,12,13,17,9,10]})

# %%
mean,cov=[1,0.5],([0.8,2],[.5,1.2])

# %%
data=np.random.multivariate_normal(mean,cov,200)
# Out:
# C:\Users\Billy Gareth\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   """Entry point for launching an IPython kernel.

# %%
# plotting
with sns.axes_style('white'):
    sns.jointplot(x=m,y=n,kind='kde',color='b')

# %% [markdown]
# # <font color ='Orange'> Multi_Plot Grids using FacetGrid() and PairGrid() to map()

# %%
a=pd.read_excel('./AdventureWorks_Database.xlsx')

# %%
a.head()
# Out:
#         Date   DateKey  Year Quarter  MonthNum Month FiscalYear FiscalQuarter  \
# 0 2016-04-03  20160403  2016      Q2         4   Apr     FY2016           FQ4
# 1 2016-04-04  20160404  2016      Q2         4   Apr     FY2016           FQ4
# 2 2016-04-05  20160405  2016      Q2         4   Apr     FY2016           FQ4
# 3 2016-04-06  20160406  2016      Q2         4   Apr     FY2016           FQ4
# 4 2016-04-07  20160407  2016      Q2         4   Apr     FY2016           FQ4
#
#    FiscalMonthNum FiscalMonth MonthYear MonthYearLong  MonthYearNum  \
# 0              10         Apr    Apr-16      Apr-2016        201604
# 1              10         Apr    Apr-16      Apr-2016        201604
# 2              10         Apr    Apr-16      Apr-2016        201604
# 3              10         Apr    Apr-16      Apr-2016        201604
# 4              10         Apr    Apr-16      Apr-2016        201604
#
#    WeekdayNum Weekday WeekdayWeekend
# 0           1     Sun        Weekend
# ...

# %%
b=sns.FacetGrid(a,col='WeekdayWeekend')
b.map(plt.hist,'FiscalYear')

# %%
#could easily analyze bivariations
b=sns.PairGrid(a)
b.map(plt.scatter)

# %% [markdown]
# # <font color='orange'> Using set for style advancing<font>

# %%
#darkgrid
sns.set(style='darkgrid')
b=sns.FacetGrid(a,col='WeekdayWeekend')
b.map(plt.hist,'FiscalYear')

# %%
#dark without grids
sns.set(style='dark')
b=sns.FacetGrid(a,col='WeekdayWeekend')
b.map(plt.hist,'FiscalYear')

# %% [markdown]
# # <font color='sky blue'>Activation of color codes<font>

# %%
sns.set(style='dark',color_codes=True)
sns.boxplot(x='FiscalYear',y='FiscalMonthNum',data=a)

# %% [markdown]
# # <font color='brown'>despine to remove axis<font>

# %%
sns.set(style='white',color_codes=True)
sns.boxplot(x='FiscalYear',y='FiscalMonthNum',data=a)
sns.despine(offset=10,trim=True)

# %% [markdown]
# # <font color='gold'>color palettes in seaborn using palplot()<font>

# %%
x=sns.color_palette()
sns.palplot(x)
